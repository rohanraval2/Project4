# %%
import pandas as pd
import numpy as np
import random
import plotly.express as px

# %%
x = [1,2,3]
print(np.random.shuffle(x))
x
# Out:
# None
# [1, 2, 3]

# %%
col = list(df['Speed-m/sec'])
df_copied = df.copy()
df_copied['Speed-m/sec'] = random.sample(col, k=len(col))
df_copied_grouped = df_copied.groupby('Group')['Speed-m/sec'].mean()
t_stastic = df_copied_grouped['Old'] - df_copied_grouped['Middle']
t_stastic
#df_copied_grouped
#df_copied.groupby('Group')['Speed-m/sec'].mean()

df_grouped = df.groupby('Group')['Speed-m/sec'].mean()
oberserved_t_stastic = df_grouped['Old'] - df_grouped['Middle']
oberserved_t_stastic

(np.sum(t > oberserved_t_stastic) / len(t)) * 100
# Out:
# 7.91

# %%
t = []
for i in range(10000):
    col = list(df['Speed-m/sec'])
    df_copied = df.copy()
    df_copied['Speed-m/sec'] = random.sample(col, k=len(col))
    df_copied_grouped = df_copied.groupby('Group')['Speed-m/sec'].mean()
    t_stastic = df_copied_grouped['Old'] - df_copied_grouped['Middle']
    t.append(t_stastic)

px.histogram(t).add_vline(x=oberserved_t_stastic, line_color='red', line_width=1.5)

# %%
df = pd.read_csv('table.csv')

# %%
df.groupby('Group')[['Speed-m/sec', 'leg-length-inches', 'weight-lbs']].mean()
df[['Speed-m/sec', 'leg-length-inches', 'weight-lbs', 'height-inches', 'age-months']].corr('pearson')
# Out:
#                    Speed-m/sec  leg-length-inches  weight-lbs  height-inches  \
# Speed-m/sec           1.000000           0.599045    0.510778       0.618910
# leg-length-inches     0.599045           1.000000    0.881006       0.940106
# weight-lbs            0.510778           0.881006    1.000000       0.943460
# height-inches         0.618910           0.940106    0.943460       1.000000
# age-months            0.652726           0.898182    0.901720       0.956615
#
#                    age-months
# Speed-m/sec          0.652726
# leg-length-inches    0.898182
# weight-lbs           0.901720
# height-inches        0.956615
# age-months           1.000000
